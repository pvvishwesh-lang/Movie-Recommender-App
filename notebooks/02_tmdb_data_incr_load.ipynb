# %%
import os
import requests
import time
from datetime import datetime, timedelta
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct

# %%
TMDB_API_KEY = os.environ.get("TMDB_API_KEY")
QDRANT_API_KEY = os.environ.get("QDRANT_API_KEY")
QDRANT_URL = os.environ.get("QDRANT_URL")

# %%
print("TMDB_API_KEY:", TMDB_API_KEY, "QDRANT_API_KEY:", QDRANT_API_KEY, "QDRANT_URL:", QDRANT_URL)
# Out:
# TMDB_API_KEY: None QDRANT_API_KEY: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIiwic3ViamVjdCI6ImFwaS1rZXk6ZTA3MTE2MjktMTdhOC00MGMzLTkxNDAtNjA5ZDZjZDZmNTM4In0.thHeMtauo7OTPFWhAAhPf2VETwrWMGLheukGTLWTTCA QDRANT_URL: None
